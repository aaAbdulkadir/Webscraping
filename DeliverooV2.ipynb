# %%
# ------------------------------------------------------- IMPORT -------------------------------------------------------
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
from selenium.webdriver.support import expected_conditions as EC, wait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support.ui import WebDriverWait
import requests

# ------------------------------------------------------- GLOBAL VARIABLE ------------------------------------------------

count = 0

# scroll
a = 0
b = 0

names = []
cuisines = []
areas = []
postcodes = []

if __name__ == "__main__":
    # read the postcodes in
    df = pd.read_csv(r"C:\Users\Abdulkadir\Documents\Programming\WebScrapeTeasdale\Completed Code\POSTCODE UK.csv")
    # change the dataframe into a list of postcodes
    df2 = df["Postcode"].to_list()
    
    for loop in df2[0:10]:
        # if post code works
        path = r"C:\Users\Abdulkadir\Documents\Programming\chromedriver.exe"
        driver = webdriver.Chrome(path)
        driver.get('https://deliveroo.co.uk/?utm_source=google&utm_medium=cpc&utm_term=deliveroo&utm_campaign=%2A%2A%5EAcquisition%5ESearch%5EBrand%5EUK%5ELondon%5E%5EExact%5EAPI%5E%5E%5E%5E%5EEN%5EStrategic%5E%C2%A311240584729&utm_loc=9044936&utm_device=c&utm_adposition=&utm_network=g&utm_targetid=kwd-52577441545&gclid=CjwKCAjw4qCKBhAVEiwAkTYsPEKhyFXk8TXpLeWEhNLlVETeIXAyzY5W0qCZqi_g2sfMsX5ed0Ry3hoCddIQAvD_BwE&gclsrc=aw.ds')

        # get to the web page with the restaurants
        wait = WebDriverWait(driver, 10)
        cookies = wait.until(EC.presence_of_element_located((By.ID, 'onetrust-accept-btn-handler')))
        cookies.click()

        search_box = wait.until(EC.presence_of_element_located((By.ID, 'location-search')))
        search_box.click()

        search_box.send_keys(f'{df2[count]}')

        search_button = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'ccl-cce251427bbe4ec4')))
        search_button.click()

        # now on the restaurant page, extract info
        x = 1

        # case 1: has restaurant
        try:
            
            pop_up = wait.until(EC.presence_of_element_located((By.XPATH, '/html/body/div[8]/div/div/div/div/div/div[2]/span[2]/button/span')))
            pop_up.click()
            
            # case a: view all
            try:
                see_all = wait.until(EC.element_to_be_clickable((By.CLASS_NAME, 'ccl-cce251427bbe4ec4')))
                actions = ActionChains(driver)
                actions.move_to_element(see_all).perform()
                see_all.click()
                time.sleep(1)
                
                driver.execute_script(f"window.scrollTo({str(0)},{str(0)})") 

                restaurant = True
                while restaurant == True:

                    # has data
                    try:
                        # list of postcodes
                        postcodes.append(df2[count])

                        # list of areas
                        area = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[2]/div/div[1]/div/div[1]/div/div[1]/div[1]/span/button/div/div[2]/div/div/div/div/span').text
                        areas.append(area)
                        print(f'{df2[count]}: {area}')
                        
                        # open
                        try:
                            name = driver.find_element_by_xpath(f'/html/body/div[1]/div/div/div[2]/div/div[2]/div/ul/li[{x}]/div/div/a/span/span[2]/div[2]/ul/li[1]/span/p').text
                            names.append(name)
                            print(name)

                        # closed
                        except :
                            name = driver.find_element_by_xpath(f'/html/body/div[1]/div/div/div[2]/div/div[2]/div/ul/li[{x}]/div/div/a/span/span[2]/div/ul/li[1]/span/p').text
                            names.append(name)
                            print(name)
                            
                        x += 1

                    # no data
                    except:
                        name = 'empty'
                        names.append('N/A')
                        print('N/A')
                        x += 1
                        
                    # cuisines
                    try:
                        print('-------------------------------------------------')
                        
                        # open
                        try:
                            cuisine = driver.find_element_by_xpath(f'/html/body/div[1]/div/div/div[2]/div/div[2]/div/ul/li[{x}]/div/div/a/span/span[2]/div[2]/ul/li[2]').text
                            cuisines.append(cuisine)
                            print(cuisine)

                        # closed
                        except:
                            cuisine = driver.find_element_by_xpath(f'/html/body/div[1]/div/div/div[2]/div/div[2]/div/ul/li[{x}]/div/div/a/span/span[2]/div/ul/li[2]').text
                            cuisines.append(cuisine)
                            print(cuisine)

                    except:
                        cuisine = 'empty'
                        cuisines.append('N/A')
                        print('N/A')
                    

                    b += 200
                    driver.execute_script(f"window.scrollTo({str(a)},{str(b)})") 

                    if name == 'empty' and x > 20:
                        restaurant = False


            # case b: no view all
            except:
                restaurant = True
                while restaurant == True:

                    # has data
                    try:
                        # list of postcodes
                        postcodes.append(df2[count])

                        # list of areas
                        area = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[2]/div/div[2]/div/div/div/div/div/h3').text
                        areas.append(area)
                        print(f'{df2[count]}: {area}')
                        
                        # open
                        try:
                            name = driver.find_element_by_xpath(f'/html/body/div[1]/div/div/div[2]/div/div[2]/div/ul/li[{x}]/div/div/a/span/span[2]/div[2]/ul/li[1]/span/p').text
                            names.append(name)
                            print(name)

                        # closed
                        except :
                            name = driver.find_element_by_xpath(f'/html/body/div[1]/div/div/div[2]/div/div[2]/div/ul/li[{x}]/div/div/a/span/span[2]/div/ul/li[1]/span/p').text
                            names.append(name)
                            print(name)
                            
                        x += 1

                    # no data
                    except:
                        name = 'empty'
                        names.append('N/A')
                        print('N/A')
                        x += 1
                        
                    # cuisines
                    try:
                        print('-------------------------------------------------')
                        
                        # open
                        try:
                            cuisine = driver.find_element_by_xpath(f'/html/body/div[1]/div/div/div[2]/div/div[2]/div/ul/li[{x}]/div/div/a/span/span[2]/div[2]/ul/li[2]').text
                            cuisines.append(cuisine)
                            print(cuisine)

                        # closed
                        except:
                            cuisine = driver.find_element_by_xpath(f'/html/body/div[1]/div/div/div[2]/div/div[2]/div/ul/li[{x}]/div/div/a/span/span[2]/div/ul/li[2]').text
                            cuisines.append(cuisine)
                            print(cuisine)

                    except:
                        cuisine = 'empty'
                        cuisines.append('N/A')
                        print('N/A')

                    b += 500
                    driver.execute_script(f"window.scrollTo({str(a)},{str(b)})")   

                    if name == 'empty' and x > 80:
                        restaurant = False
                
            driver.quit()
            count += 1

        # case 2: has no restaurants
        except:
            print('error1')
            driver.quit()
            count += 1
            
        print('--------------------------------------------------------------------------------------------')
            
        
        
    # pandas
    data = pd.DataFrame({'Postcode': postcodes, 'Area': areas, 'Restaurant': names, 'Cuisines': cuisines})
    dataCSV = data.to_csv(r"C:\Users\Abdulkadir\Documents\Programming\WebScrapeTeasdale\Deliveroo\DeliverooV2\DeliverooV2_0-300.csv")
    print('-----------------------------DONE-----------------------------')
    print(data)
# Out:
# AB10 1AA: Ruthrieston
# KFC
# -------------------------------------------------
# 4.1 Good(500+)·American·Burgers
# AB10 1AA: Ruthrieston
# Burger King
# -------------------------------------------------
# 4.6 Excellent(500+)·Salads·Breakfast·Sandwiches·Healthy
# AB10 1AA: Ruthrieston
# Pret A Manger
# -------------------------------------------------
# 4.4 Very Good(500+)·American·Burgers·Milkshakes
# AB10 1AA: Ruthrieston
# Five Guys - Burger and Fries
# -------------------------------------------------
# 4.3 Very Good(500+)·American·Sandwiches·Chicken·Healthy
# AB10 1AA: Ruthrieston
# Subway
# -------------------------------------------------
# 4.6 Excellent(500+)·Burritos·Mexican·Burgers
# AB10 1AA: Ruthrieston
# FreshMex
# -------------------------------------------------
# 4.5 Excellent(500+)·Grocery·Drinks·Dessert·Alcohol
# AB10 1AA: Ruthrieston
# Co-op - Aberdeen - 204 Union Street
# -------------------------------------------------
# 4.6 Excellent(15)·British·Sandwiches
# AB10 1AA: Ruthrieston
# Birchtree Sandwich Shop
# -------------------------------------------------
# 4.4 Very Good(500+)·Noodles·Asian·Japanese·Chinese
# AB10 1AA: Ruthrieston
# Dr Noodles
# -------------------------------------------------
# 4.5 Excellent(500+)·Grocery·Drinks·Alcohol·Dessert
# AB10 1AA: Ruthrieston
# Sainsbury's
# -------------------------------------------------
# 4.4 Very Good(500+)·British·Coffee·Breakfast·Burgers
# AB10 1AA: Ruthrieston
# Cafe 100
# -------------------------------------------------
# 4.2 Very Good(500+)·Mexican·Tacos·Burritos
# AB10 1AA: Ruthrieston
# Taco Bell
# -------------------------------------------------
# 4.0 Good(500+)·Noodles·Chinese·Asian
# AB10 1AA: Ruthrieston
# Chopstix Noodle Bar
# -------------------------------------------------
# 4.4 Very Good(500+)·Dessert
# AB10 1AA: Ruthrieston
# Thains Bakery
# -------------------------------------------------
# 4.6 Excellent(500+)·British·Brunch·Sandwiches·Salads
# AB10 1AA: Ruthrieston
# Grub Fresh Food
# -------------------------------------------------
# 4.4 Very Good(17)·Turkish·Burgers·Pizza·Wraps
# AB10 1AA: Ruthrieston
# Anatolia Kebab House
# -------------------------------------------------
# 4.4 Very Good(500+)·Chicken·Burgers
# AB10 1AA: Ruthrieston
# Nando's
# -------------------------------------------------
# 4.5 Excellent(500+)
# AB10 1AA: Ruthrieston
# Pepe's Piri Piri
# -------------------------------------------------
# 4.5 Excellent(500+)·Grocery·Drinks·Dessert·Alcohol
# AB10 1AA: Ruthrieston
# Co-op
# -------------------------------------------------
# 4.3 Very Good(500+)·Curry·Asian·Ramen·Japanese
# AB10 1AA: Ruthrieston
# Wagamama
# -------------------------------------------------
# 4.6 Excellent(500+)·Breakfast·Smoothie·Drinks
# AB10 1AA: Ruthrieston
# Corner Tree Cafe
# -------------------------------------------------
# 4.4 Very Good(500+)·Fish and chips·British·Seafood·Burgers
# AB10 1AA: Ruthrieston
# The Dolphin Fish and Chips Takeaway and Restaurant
# -------------------------------------------------
# 4.7 Excellent(500+)·Sandwiches·Grocery·Alcohol
# AB10 1AA: Ruthrieston
# Ferryhill Stores
# -------------------------------------------------
# 4.5 Excellent(500+)·Italian·Pasta
# AB10 1AA: Ruthrieston
# Coco di Mama Kitchens
# -------------------------------------------------
# 4.2 Very Good(500+)·Fish and chips·British
# AB10 1AA: Ruthrieston
# Low’s Traditional Fish & Chips
# -------------------------------------------------
# 4.0 Good(53)·American·Sandwiches·Breakfast·Café
# AB10 1AA: Ruthrieston
# Starbucks ®
# -------------------------------------------------
# 4.7 Excellent(500+)·Bubble tea·Asian
# AB10 1AA: Ruthrieston
# Tchit 沏茶
# -------------------------------------------------
# 4.1 Good(444)·British·Burgers·Breakfast
# AB10 1AA: Ruthrieston
# Granmas Kitchen
# -------------------------------------------------
# 4.5 Excellent(500+)·Pizza·Italian·Dessert·Pasta
# AB10 1AA: Ruthrieston
# PIZZAEXPRESS
# -------------------------------------------------
# 4.7 Excellent(500+)·Grocery·Alcohol
# AB10 1AA: Ruthrieston
# Aldi
# -------------------------------------------------
# 4.6 Excellent(489)·Sandwiches·Burgers
# AB10 1AA: Ruthrieston
# The Tartan Pig
# -------------------------------------------------
# 4.4 Very Good(500+)·Thai·Noodles·Curry·Asian
# AB10 1AA: Ruthrieston
# Thaikhun
# -------------------------------------------------
# 4.5 Excellent(500+)·Chicken·Breakfast
# AB10 1AA: Ruthrieston
# Pavilion Cafe
# -------------------------------------------------
# 4.0 Good(429)·Noodles·Chinese·Asian
# AB10 1AA: Ruthrieston
# Chopstix
# -------------------------------------------------
# 4.0 Good(500+)·Pizza·Dessert·American·Italian
# AB10 1AA: Ruthrieston
# Pizza Hut Restaurants
# -------------------------------------------------
# 4.6 Excellent(500+)·Donuts·Dessert·American·Milkshakes
# AB10 1AA: Ruthrieston
# Krispy Kreme
# -------------------------------------------------
# 4.6 Excellent(471)·Sandwiches·Breakfast·Coffee
# AB10 1AA: Ruthrieston
# Costa Coffee
# -------------------------------------------------
# 4.3 Very Good(421)·Tea·Ice cream·Smoothie·Sandwiches
# AB10 1AA: Ruthrieston
# The Pier
# -------------------------------------------------
# 4.3 Very Good(500+)·Drinks·Grocery·BBQ·Alcohol
# AB10 1AA: Ruthrieston
# Morrisons
# -------------------------------------------------
# 4.3 Very Good(500+)·Pizza·Italian·Alcohol
# AB10 1AA: Ruthrieston
# Zizzi
# -------------------------------------------------
# 4.8 Excellent(94)·Café·Breakfast
# AB10 1AA: Ruthrieston
# Cup
# -------------------------------------------------
# 4.5 Excellent(152)·British·Café·Bagels·Sandwiches
# AB10 1AA: Ruthrieston
# Muffin Break
# -------------------------------------------------
# 4.1 Good(28)·British
# AB10 1AA: Ruthrieston
# Baguette Express
# -------------------------------------------------
# 4.3 Very Good(500+)·Pizza·Italian·American·Dessert
# AB10 1AA: Ruthrieston
# Pizza Hut Delivery
# -------------------------------------------------
# 4.8 Excellent(500+)·British·Breakfast
# AB10 1AA: Ruthrieston
# BioCafe
# -------------------------------------------------
# 3.8 Good(269)·Indian·Chinese·Noodles·Curry
# AB10 1AA: Ruthrieston
# Yangtze
# -------------------------------------------------
# 4.3 Very Good(500+)·Dessert·Burgers·Breakfast·Bagels
# AB10 1AA: Ruthrieston
# Ross Bakery
# -------------------------------------------------
# 4.6 Excellent(436)·Breakfast·Café
# AB10 1AA: Ruthrieston
# Books and Beans
# -------------------------------------------------
# 4.0 Good(438)·Dessert·Ice cream·Alcohol
# AB10 1AA: Ruthrieston
# Cream Temptations
# -------------------------------------------------
# 4.6 Excellent(500+)·Brunch·British·Breakfast·Burgers
# AB10 1AA: Ruthrieston
# Union Cafe & Bistro
# -------------------------------------------------
# 3.8 Good(24)·American·British·Ice cream
# AB10 1AA: Ruthrieston
# Cafe Crema
# -------------------------------------------------
# 4.5 Excellent(500+)·Pizza·Italian·Pasta
# AB10 1AA: Ruthrieston
# ASK Italian Pasta & Pizza
# -------------------------------------------------
# 4.5 Excellent(233)·Dessert·Brunch·Sandwiches·Bakery
# AB10 1AA: Ruthrieston
# Patisserie Valerie
# -------------------------------------------------
# 4.6 Excellent(191)·Grocery·Healthy
# AB10 1AA: Ruthrieston
# LloydsPharmacy
# -------------------------------------------------
# 3.3(57)·Indian·Chinese·Curry·Chicken
# AB10 1AA: Ruthrieston
# Jaldi Jaldi
# -------------------------------------------------
# 4.3 Very Good(177)·Sandwiches·Café·British·Burgers
# AB10 1AA: Ruthrieston
# The Highlander Cafe Bus
# -------------------------------------------------
# Drinks·Grocery
# AB10 1AA: Ruthrieston
# Crown News
# -------------------------------------------------
# 4.7 Excellent(149)·Drinks·Grocery
# AB10 1AA: Ruthrieston
# PREMIER Byron Stores
# -------------------------------------------------
# 4.5 Excellent(500+)·Italian·Pasta
# AB10 1AA: Ruthrieston
# GRATE
# -------------------------------------------------
# 4.3 Very Good(280)·Alcohol·Drinks·Grocery
# AB10 1AA: Ruthrieston
# Premier City News
# -------------------------------------------------
# 4.8 Excellent(500+)·Alcohol·Grocery
# AB10 1AA: Ruthrieston
# Zabka
# -------------------------------------------------
# British
# AB10 1AA: Ruthrieston
# Full Life fundraising
# -------------------------------------------------
# 3.8 Good(38)·Pizza·American
# AB10 1AA: Ruthrieston
# Papa Johns
# -------------------------------------------------
# 4.9 Excellent(277)·Alcohol·Drinks·Wine·Grocery
# AB10 1AA: Ruthrieston
# Majestic Wine
# -------------------------------------------------
# 4.5 Excellent(22)·British·Coffee
# AB10 1AA: Ruthrieston
# Cafe Creo
# -------------------------------------------------
# 4.3 Very Good(500+)·Spanish·Seafood·Tapas·Alcohol
# AB10 1AA: Ruthrieston
# Cafe Andaluz
# -------------------------------------------------
# 4.1 Good(500+)·Burritos·Mexican·Tacos
# AB10 1AA: Ruthrieston
# Paco's Tacos
# -------------------------------------------------
# 4.3 Very Good(500+)·Pizza·American
# AB10 1AA: Ruthrieston
# Papa John's
# -------------------------------------------------
# 4.2 Very Good(333)·British·American·Burgers
# AB10 1AA: Ruthrieston
# Low's Handmade Gourmet Steak Burgers
# -------------------------------------------------
# 4.7 Excellent(261)·Sandwiches·Grocery
# AB10 1AA: Ruthrieston
# Londis
# -------------------------------------------------
# 3.7 Good(53)·Italian·Pizza
# AB10 1AA: Ruthrieston
# Pizza D.O.C
# -------------------------------------------------
# 3.8 Good(500+)·American·Burgers·Chicken·Fish and chips
# AB10 1AA: Ruthrieston
# Munchie Box
# -------------------------------------------------
# Romanian·Chicken·Alcohol·Coffee
# AB10 1AA: Ruthrieston
# Authentic Romanian Shop
# -------------------------------------------------
# 4.5 Excellent(350)·Grocery·Drinks
# AB10 1AA: Ruthrieston
# Rosemount Convenience Store
# -------------------------------------------------
# 4.5 Excellent(500+)·Dessert·Alcohol·Grocery
# AB10 1AA: Ruthrieston
# Sunnys Convenience Store
# -------------------------------------------------
# 4.4 Very Good(500+)·British·Alcohol·Grocery
# AB10 1AA: Ruthrieston
# Adie's Self Service
# -------------------------------------------------
# 4.2 Very Good(378)·Italian·Pasta·Pizza·Mediterranean
# AB10 1AA: Ruthrieston
# Amarone
# -------------------------------------------------
# 4.6 Excellent(215)·Chicken·Middle Eastern·Steak·Grocery
# AB10 1AA: Ruthrieston
# Fair Deal Foods ltd
# -------------------------------------------------
# 4.4 Very Good(500+)·Pizza·Chicken·Drinks·Brunch
# AB10 1AA: Ruthrieston
# Big Mannys Pizza
# -------------------------------------------------
# 4.2 Very Good(500+)·American·British·Burgers·Grill
# AB10 1AA: Ruthrieston
# STACKS
# -------------------------------------------------
# 4.6 Excellent(500+)·Burritos·Tacos·Mexican·Burgers
# AB10 1AA: Ruthrieston
# Latinway
# -------------------------------------------------
# 4.3 Very Good(500+)·American·Fried chicken·Chicken
# AB10 1AA: Ruthrieston
# Bird Box
# -------------------------------------------------
# 4.2 Very Good(500+)·Pizza·American·Burgers·Italian
# AB10 1AA: Ruthrieston
# Frankie & Benny's
# -------------------------------------------------
# 4.0 Good(273)·American·British·Burgers·Chicken
# AB10 1AA: Ruthrieston
# STACKS - Aberdeen Beach
# -------------------------------------------------
# 3.5(55)·Fried chicken·Chicken·Wings·American
# AB10 1AA: Ruthrieston
# Lucky 7
# -------------------------------------------------
# 4.4 Very Good(342)·Grill·Chicken·Wings·BBQ
# AB10 1AA: Ruthrieston
# BONE JAM
# -------------------------------------------------
# 4.1 Good(325)·British·Burgers·Tapas
# AB10 1AA: Ruthrieston
# All Bar One
# -------------------------------------------------
# 4.5 Excellent(500+)·Thai·Noodles·Curry
# AB10 1AA: Ruthrieston
# Chaophraya
# -------------------------------------------------
# 4.2 Very Good(500+)·Burgers·Chicken·American·Fried chicken
# AB10 1AA: Ruthrieston
# Fridays
# -------------------------------------------------
# 4.1 Good(43)·Burritos·Mexican·Chicken
# AB10 1AA: Ruthrieston
# Kick Ass Burrito - Aberdeen Beach
# -------------------------------------------------
# 3.9 Good(67)·Burgers·Chicken
# AB10 1AA: Ruthrieston
# Harvester
# -------------------------------------------------
# 4.2 Very Good(78)·British·Chicken·Pie
# AB10 1AA: Ruthrieston
# Devonly Pies
# -------------------------------------------------
# 3.7 Good(14)·Dessert·Ice cream·American·Donuts
# AB10 1AA: Ruthrieston
# Puddo - Aberdeen Beach
# -------------------------------------------------
# 3.9 Good(94)·Dessert·Ice cream·American·Donuts
# AB10 1AA: Ruthrieston
# Puddo
# -------------------------------------------------
# 4.2 Very Good(68)·Grill·Chicken·Wings·American
# AB10 1AA: Ruthrieston
# Bone Jam
# -------------------------------------------------
# Alcohol·Coffee·Wine
# AB10 1AA: Ruthrieston
# Cheerz
# -------------------------------------------------
# 4.2 Very Good(500+)·Japanese·Sushi·Chicken·Asian
# AB10 1AA: Ruthrieston
# YO!
# -------------------------------------------------
# 4.6 Excellent(500+)·Dessert·British·Brunch·Italian
# AB10 1AA: Ruthrieston
# Crolla's
# -------------------------------------------------
# 4.2 Very Good(500+)·Cantonese·Chinese
# AB10 1AA: Ruthrieston
# Golden Crown Chinese
# -------------------------------------------------
# 4.3 Very Good(15)·British·Breakfast
# AB10 1AA: Ruthrieston
# Lows Traditional Breakfasts
# -------------------------------------------------
# 4.1 Good(500+)·Turkish·Kebab·Pizza·Burgers
# AB10 1AA: Ruthrieston
# Marmaris Kebab
# -------------------------------------------------
# 4.5 Excellent(500+)·Chicken·BBQ·Sandwiches·Brunch
# AB10 1AA: Ruthrieston
# Smoke And Soul
# -------------------------------------------------
# 4.6 Excellent(500+)·American·Dessert·Ice cream·Milkshakes
# AB10 1AA: Ruthrieston
# Baskin Robbins
# -------------------------------------------------
# 4.4 Very Good(500+)·Burritos·Mexican
# AB10 1AA: Ruthrieston
# Muchacho Rose St
# -------------------------------------------------
# 4.5 Excellent(500+)·Chicken·Asian·Noodles·Thai
# AB10 1AA: Ruthrieston
# Asian Magic Kitchen
# -------------------------------------------------
# 4.0 Good(500+)·Pizza·Pasta·Italian
# AB10 1AA: Ruthrieston
# Tony Macaroni
# -------------------------------------------------
# 4.5 Very Good(156)·Bubble tea·Drinks
# AB10 1AA: Ruthrieston
# Bubble CiTea
# -------------------------------------------------
# 4.5 Excellent(500+)·Curry·Indian
# AB10 1AA: Ruthrieston
# The Everest
# -------------------------------------------------
# 4.6 Excellent(500+)·Brunch·Healthy·Breakfast·Café
# AB10 1AA: Ruthrieston
# The Eggxorcist
# -------------------------------------------------
# 4.5 Excellent(500+)·Chinese·Noodles
# AB10 1AA: Ruthrieston
# Slow Boat
# -------------------------------------------------
# 4.6 Excellent(500+)·British·Burgers·Chicken·Fish and chips
# AB10 1AA: Ruthrieston
# Hass's Fish & Chip Shop
# -------------------------------------------------
# 4.4 Very Good(500+)·British·Fish and chips
# AB10 1AA: Ruthrieston
# Bluebird Fishbar
# -------------------------------------------------
# 4.4 Very Good(500+)·Chinese·Seafood
# AB10 1AA: Ruthrieston
# New China
# -------------------------------------------------
# 4.6 Excellent(500+)·Turkish·Mezze
# AB10 1AA: Ruthrieston
# Nargile
# -------------------------------------------------
# 4.3 Very Good(500+)·British·Fish and chips
# AB10 1AA: Ruthrieston
# Seaton Chipper
# -------------------------------------------------
# 4.5 Excellent(500+)·Curry·Indian
# AB10 1AA: Ruthrieston
# Shri Bheema's Indian Restaurant
# -------------------------------------------------
# 4.1 Good(500+)·American·Alcohol·Burgers·Drinks
# AB10 1AA: Ruthrieston
# BrewDog Beers & Burgers
# -------------------------------------------------
# 4.4 Very Good(500+)·Curry·Indian
# AB10 1AA: Ruthrieston
# Rishis Indian Aroma
# -------------------------------------------------
# 4.6 Excellent(500+)·Pizza·Pasta
# AB10 1AA: Ruthrieston
# AJ's Pizza and Pasta
# -------------------------------------------------
# 4.4 Very Good(500+)·Italian·Pizza·Pasta
# AB10 1AA: Ruthrieston
# Amore
# -------------------------------------------------
# 4.3 Very Good(500+)·Indian·Dim Sum·Curry
# AB10 1AA: Ruthrieston
# Wild Ginger Restaurant
# -------------------------------------------------
# 4.1 Good(500+)·American·Dessert·Donuts·Pancakes
# AB10 1AA: Ruthrieston
# Krepes n Kones
# -------------------------------------------------
# 4.6 Excellent(500+)·Indian·Curry
# AB10 1AA: Ruthrieston
# 8848 Restaurant
# -------------------------------------------------
# 4.2 Very Good(500+)·Pizza·Turkish·Kebab
# AB10 1AA: Ruthrieston
# Bodrum Kebab House
# -------------------------------------------------
# 4.6 Excellent(500+)·Chinese·Chicken·Seafood·Noodles
# AB10 1AA: Ruthrieston
# Siam Cottage
# -------------------------------------------------
# 4.0 Good(66)·Milkshakes·Dessert·Grill·Bubble tea
# AB10 1AA: Ruthrieston
# Flakes Diner
# -------------------------------------------------
# 4.3 Very Good(15)
# AB10 1AA: Ruthrieston
# AJs Pizza & Pasta
# -------------------------------------------------
# Curry·Noodles·Malaysian
# AB10 1AA: Ruthrieston
# Mary’s Kitchen
# -------------------------------------------------
# 4.7 Excellent(500+)·British·Sandwiches·Dessert·Breakfast
# AB10 1AA: Ruthrieston
# The Long Dog Cafe
# -------------------------------------------------
# 4.3 Very Good(394)·Chinese·Dim Sum
# AB10 1AA: Ruthrieston
# Saigon Restaurant
# -------------------------------------------------
# 4.1 Good(48)·Curry·Indian·Pizza
# AB10 1AA: Ruthrieston
# Blue Spice Takeaway
# -------------------------------------------------
# 4.3 Very Good(135)·Tea·Soup·Thai
# AB10 1AA: Ruthrieston
# Royal Thai
# -------------------------------------------------
# 4.2 Very Good(500+)·Italian·Burgers·Chicken·Pizza
# AB10 1AA: Ruthrieston
# Rainbow Italian Food
# -------------------------------------------------
# 4.6 Excellent(500+)·Middle Eastern·Falafel
# AB10 1AA: Ruthrieston
# Falafel Delight
# -------------------------------------------------
# 4.1 Good(456)·Ice cream·Dessert·Milkshakes·American
# AB10 1AA: Ruthrieston
# Sweet Dreams
# -------------------------------------------------
# 4.4 Very Good(500+)·Caribbean·Jamaican·Chicken·Seafood
# AB10 1AA: Ruthrieston
# Tango Turtle - Caribbean Inspired Food
# -------------------------------------------------
# 4.6 Excellent(500+)·British·Burgers·Chicken·American
# AB10 1AA: Ruthrieston
# St Machar Bar
# -------------------------------------------------
# 4.0 Good(25)·Turkish
# AB10 1AA: Ruthrieston
# Efe Pizza House
# -------------------------------------------------
# 4.2 Good(83)·Chinese·Thai·Chicken
# AB10 1AA: Ruthrieston
# Feng Wei Takeaway
# -------------------------------------------------
# 4.2 Very Good(43)·Chinese
# AB10 1AA: Ruthrieston
# Hi Oishii
# -------------------------------------------------
# 3.6 Good(500+)·Pizza·Italian·Pasta·Alcohol
# AB10 1AA: Ruthrieston
# Prezzo
# -------------------------------------------------
# 4.0 Good(500+)·Pizza·Burgers·Chicken·Kebab
# AB10 1AA: Ruthrieston
# Belmont Pizza
# -------------------------------------------------
# 4.2 Very Good(448)·Burgers·Chicken·Wings·American
# AB10 1AA: Ruthrieston
# Jailbreak Chicken
# -------------------------------------------------
# 4.1 Good(62)·Chicken·Portuguese
# AB10 1AA: Ruthrieston
# Zees Peri Peri Grill
# -------------------------------------------------
# 4.5 Excellent(28)·Chicken·Café
# AB10 1AA: Ruthrieston
# Second Home Studio and Cafe
# -------------------------------------------------
# 4.2 Very Good(500+)·British·Fish and chips
# AB10 1AA: Ruthrieston
# Woodend Fish Bar
# -------------------------------------------------
# 3.5 Good(500+)·Kebab·Fried chicken·British
# AB10 1AA: Ruthrieston
# The Tastie Tattie
# -------------------------------------------------
# 3.8 Good(25)·Wraps·Burgers·Pizza
# AB10 1AA: Ruthrieston
# Aberedeen Pizza & Burgers
# -------------------------------------------------
# 4.5 Excellent(465)·Chicken·Curry·Indian·Alcohol
# AB10 1AA: Ruthrieston
# The South Indian
# -------------------------------------------------
# 3.6 Good(500+)·Pizza·Kebab·Fish and chips·Breakfast
# AB10 1AA: Ruthrieston
# GET STUFFED
# -------------------------------------------------
# 4.4 Very Good(378)·Curry·Indian·Nepalese
# AB10 1AA: Ruthrieston
# Gurkha Kitchen Takeaway
# -------------------------------------------------
# 4.2 Very Good(500+)·Pizza·Italian
# AB10 1AA: Ruthrieston
# Snappy Tomato Pizza
# -------------------------------------------------
# 4.4 Very Good(215)·Curry·Indian
# AB10 1AA: Ruthrieston
# Shabaaz Tandoori
# -------------------------------------------------
# 4.3 Very Good(201)·Indian
# AB10 1AA: Ruthrieston
# Riksha Streetside Indian
# -------------------------------------------------
# 4.4 Very Good(260)·Curry·Indian
# AB10 1AA: Ruthrieston
# Curry Mount Indian Takeaway
# -------------------------------------------------
# Turkish·Kebab·Burgers·Pizza
# AB10 1AA: Ruthrieston
# Pasha Kebabs
# -------------------------------------------------
# 3.8 Good(33)·Chinese·Chicken·Asian
# AB10 1AA: Ruthrieston
# Good Neighbour at Fantasy Wok
# -------------------------------------------------
# 4.2 Very Good(313)·American·Burgers
# AB10 1AA: Ruthrieston
# Rehmat's
# -------------------------------------------------
# 4.0 Good(93)·Burritos·Sandwiches·Cuban·Latin American
# AB10 1AA: Ruthrieston
# Cuban Sandwich Shop
# -------------------------------------------------
# 4.5 Excellent(415)·Italian·Pasta·Pizza
# AB10 1AA: Ruthrieston
# Cafe Harmony
# -------------------------------------------------
# 4.1 Good(268)·Pizza
# AB10 1AA: Ruthrieston
# Little Italy Pizza
# -------------------------------------------------
# 4.5 Excellent(80)·Indian·Curry
# AB10 1AA: Ruthrieston
# Gurkha Curry House
# -------------------------------------------------
# 4.4 Very Good(127)·Pizza·Indian·Burgers·Chicken
# AB10 1AA: Ruthrieston
# Aberdeen Tandoori
# -------------------------------------------------
# 4.4 Very Good(96)·Turkish·Kebab
# AB10 1AA: Ruthrieston
# Lahore Karahi
# -------------------------------------------------
# 4.5 Excellent(21)·American·Chicken·Wings·Burgers
# AB10 1AA: Ruthrieston
# Epic Chicken Grosvenor
# -------------------------------------------------
# 3.8 Good(19)·British·Fish and chips
# AB10 1AA: Ruthrieston
# The Kingfish Inn
# -------------------------------------------------
# 4.5 Excellent(115)·Sandwiches·Alcohol·Grocery
# AB10 1AA: Ruthrieston
# Premier Express
# -------------------------------------------------
# 3.8 Good(16)·American·Indian·BBQ
# AB10 1AA: Ruthrieston
# Spication
# -------------------------------------------------
# Turkish
# AB10 1AA: Ruthrieston
# Efe Turkish Kebab And Pizza House
# -------------------------------------------------
# 4.4 Very Good(134)·Grocery·Alcohol·Ice cream·Wine
# AB10 1AA: Ruthrieston
# Crown Mini Market
# -------------------------------------------------
# 4.2 Very Good(187)·British·Pizza·Dessert·Burgers
# AB10 1AA: Ruthrieston
# Marcos Fast Food
# -------------------------------------------------
# 4.5 Excellent(62)·Indian·Chicken·Curry
# AB10 1AA: Ruthrieston
# Mount Everest
# -------------------------------------------------
# Chicken·Fried chicken·Western·Burgers
# AB10 1AA: Ruthrieston
# Hungry Dog Limited
# -------------------------------------------------
# 4.5 Excellent(68)·Indian·Curry
# AB10 1AA: Ruthrieston
# Namaste Delhi
# -------------------------------------------------
# 4.3 Very Good(62)·Indian·Breakfast·Mexican·Burgers
# AB10 1AA: Ruthrieston
# Old Croft Kebab House
# -------------------------------------------------
# 3.7 Good(119)·Thai·Curry·Noodles·Indian
# AB10 1AA: Ruthrieston
# Donian
# -------------------------------------------------
# 4.1 Good(24)·Turkish·Kebab·Pizza·Burgers
# AB10 1AA: Ruthrieston
# Alaqsa Takeaway
# -------------------------------------------------
# Noodles·Western·Fish and chips·Chinese
# AB10 1AA: Ruthrieston
# Ocean Fish Bar & Chinese Takeaway
# -------------------------------------------------
# 4.5 Excellent(113)·Alcohol
# AB10 1AA: Ruthrieston
# L & M Stores
# -------------------------------------------------
# 4.1 Good(420)·British·Café·Sandwiches·Breakfast
# AB10 1AA: Ruthrieston
# The Tasty Thistle
# -------------------------------------------------
# 4.5 Excellent(230)·Sushi·Chicken·Seafood·Japanese
# AB10 1AA: Ruthrieston
# The Sushi Box
# -------------------------------------------------
# British·Fish and chips
# AB10 1AA: Ruthrieston
# Joeys Fish & Chips
# -------------------------------------------------
#
# AB10 1AA: Ruthrieston
# Scoopy Cream
# -------------------------------------------------
# 4.8 Excellent(13)·Drinks·Alcohol
# AB10 1AA: Ruthrieston
# Thistle News
# -------------------------------------------------
# 3.9 Good(146)·Kebab·Burgers·Turkish·Mediterranean
# AB10 1AA: Ruthrieston
# Wraps
# -------------------------------------------------
# 4.2 Very Good(443)·Curry·Indian
# AB10 1AA: Ruthrieston
# Monsoona Healthy Indian Cuisine
# -------------------------------------------------
# 3.8 Good(25)·Kebab·Indian
# AB10 1AA: Ruthrieston
# Spiceation
# -------------------------------------------------
# Alcohol·Pizza·Drinks
# AB10 1AA: Ruthrieston
# BrewDog Beers & Pizzas
# -------------------------------------------------
# 4.1 Good(76)·Burritos·Mexican·Chicken
# AB10 1AA: Ruthrieston
# Kick Ass Burrito
# -------------------------------------------------
# 3.1(18)·British·Fish and chips
# AB10 1AA: Ruthrieston
# Harry Ramsden's
# -------------------------------------------------
# 4.2 Very Good(107)·Breakfast·Dessert·Burgers·Cakes
# AB10 1AA: Ruthrieston
# Tasty Delight Cafe & Dessert
# -------------------------------------------------
# 2.8(16)·American·Burgers·Pizza
# AB10 1AA: Ruthrieston
# American Burger
# -------------------------------------------------
# Burgers·Breakfast·Steak
# AB10 1AA: Ruthrieston
# The Noose and Monkey
# -------------------------------------------------
# Indian·Curry·Pizza
# AB10 1AA: Ruthrieston
# Royal Masala Tandoori
# -------------------------------------------------
# 4.3 Very Good(20)·Pie
# AB10 1AA: Ruthrieston
# Pieminister Grosvenor
# -------------------------------------------------
# 3.5 Good(13)·Pizza
# AB10 1AA: Ruthrieston
# Papapizza
# -------------------------------------------------
# Indian·Drinks
# AB10 1AA: Ruthrieston
# Essence Indian Cuisine
# -------------------------------------------------
# Pizza·American·Kebab
# AB10 1AA: Ruthrieston
# Pizza Delivery Aberdeen
# -------------------------------------------------
# 4.0 Good(500+)·Noodles·Chinese
# AB10 1AA: Ruthrieston
# Zen Oriental
# -------------------------------------------------
# 4.0 Good(11)·Curry·Indian
# AB10 1AA: Ruthrieston
# Nurtaj
# -------------------------------------------------
# 3.8 Good(64)·Thai·Curry·Chinese
# AB10 1AA: Ruthrieston
# Golden Crown Thai
# -------------------------------------------------
# 4.2 Very Good(500+)·Dessert·American·Ice cream
# AB10 1AA: Ruthrieston
# Shakes n Cakes
# -------------------------------------------------
# 4.2 Very Good(500+)·Italian·Pizza
# AB10 1AA: Ruthrieston
# Mozza
# -------------------------------------------------
# 4.6 Excellent(500+)·Wings
# AB10 1AA: Ruthrieston
# The Pigs Wings
# -------------------------------------------------
# 4.8 Excellent(500+)·British·Dessert
# AB10 1AA: Ruthrieston
# Mackies19.2
# -------------------------------------------------
# 4.5 Excellent(500+)·British·Breakfast·Brunch·Sandwiches
# AB10 1AA: Ruthrieston
# Cafe Ahoy
# -------------------------------------------------
# 4.5 Excellent(500+)·Italian·Pizza
# AB10 1AA: Ruthrieston
# Rustico Restaurant
# -------------------------------------------------
# 4.2 Very Good(500+)·British·Fish and chips·Dessert·Burgers
# AB10 1AA: Ruthrieston
# The Frying Scotsman - Aberdeen
# -------------------------------------------------
# 4.4 Very Good(327)
# AB10 1AA: Ruthrieston
# Toby Carvery - Cocket Hat
# -------------------------------------------------
# 4.5 Excellent(500+)·Curry·Indian
# AB10 1AA: Ruthrieston
# The Blue Elephant Tandoori Takeaway
# -------------------------------------------------
# 4.5 Excellent(465)
# AB10 1AA: Ruthrieston
# How Bao Now
# -------------------------------------------------
# 4.2 Very Good(500+)·British·Sandwiches·Burgers·Fish and chips
# AB10 1AA: Ruthrieston
# Bridge Street Social Club
# -------------------------------------------------
# 4.3 Very Good(500+)·Turkish·Pizza·Burgers·Breakfast
# AB10 1AA: Ruthrieston
# Antalya Turkish Bakery and Kebab House
# -------------------------------------------------
# 4.4 Very Good(500+)·Curry·Indian·Pizza
# AB10 1AA: Ruthrieston
# Khyber Pass
# -------------------------------------------------
# 4.6 Excellent(411)·Turkish·Chicken·Seafood·Pasta
# AB10 1AA: Ruthrieston
# Turkish Kitchen Bar & Grill
# -------------------------------------------------
# 4.3 Very Good(500+)·Chinese·Chicken
# AB10 1AA: Ruthrieston
# Fusion
# -------------------------------------------------
# 3.8 Good(500+)·Pizza·Indian·Burgers·Kebab
# AB10 1AA: Ruthrieston
# Asian Bites
# -------------------------------------------------
# 4.4 Very Good(214)·Thai·Chicken
# AB10 1AA: Ruthrieston
# Kin Kao Thai
# -------------------------------------------------
# 4.5 Excellent(70)·Bagels·American·Dessert
# AB10 1AA: Ruthrieston
# Dizzys Sweets
# -------------------------------------------------
# 4.0 Good(70)·British·Fish and chips
# AB10 1AA: Ruthrieston
# Back Hilton Fish Bar
# -------------------------------------------------
# 4.2 Very Good(500+)·Greek·British
# AB10 1AA: Ruthrieston
# Sizzle BBQ & Grill
# -------------------------------------------------
# 4.7 Excellent(335)·Chicken·Noodles·Seafood·Thai
# AB10 1AA: Ruthrieston
# Siam Cottage
# -------------------------------------------------
# 4.4 Very Good(487)·American·Burgers·Drinks·Pizza
# AB10 1AA: Ruthrieston
# Biff's Vegan Burgers and Wingz
# -------------------------------------------------
# British·Fish and chips
# AB10 1AA: Ruthrieston
# Oor Wullie's Braw Fish & Chips
# -------------------------------------------------
# British·Fish and chips
# AB10 1AA: Ruthrieston
# Rosehill Fish Bar
# -------------------------------------------------
# Mexican·Kebab
# AB10 1AA: Ruthrieston
# Burrito and Shawarma
# -------------------------------------------------
# American·Western·Burgers·Pizza
# AB10 1AA: Ruthrieston
# Reset
# -------------------------------------------------
# 3.9 Good(20)·Portuguese·Grill·Chicken·Fried chicken
# AB10 1AA: Ruthrieston
# Zulus Peri Peri
# -------------------------------------------------
# Cakes·Dessert·Ice cream
# AB10 1AA: Ruthrieston
# Tutto Gelato
# -------------------------------------------------
# British·Steak·BBQ
# AB10 1AA: Ruthrieston
# Turkish Tonight by Cartoos
# -------------------------------------------------
# 4.5 Excellent(175)·Healthy·British
# AB10 1AA: Ruthrieston
# Halo Kitchen
# -------------------------------------------------
# 3.8 Good(117)·Ice cream·Dessert
# AB10 1AA: Ruthrieston
# Sweetland
# -------------------------------------------------
# 4.0 Good(100)·Pizza·Italian·Burgers·Kebab
# AB10 1AA: Ruthrieston
# King Kebab 119
# -------------------------------------------------
# 4.1 Good(23)·Cantonese·Chinese
# AB10 1AA: Ruthrieston
# Chinatown Restaurant
# -------------------------------------------------
# 4.0 Good(71)·Indian·Curry
# AB10 1AA: Ruthrieston
# The Nawaabs
# -------------------------------------------------
# 4.7 Excellent(474)
# AB10 1AA: Ruthrieston
# Goulash Hungarian Restaurant
# -------------------------------------------------
# 4.0 Good(500+)·Italian·Pizza·Pasta
# AB10 1AA: Ruthrieston
# La Lombarda
# -------------------------------------------------
# 3.9 Good(117)·British·Sandwiches·Milkshakes·Pie
# AB10 1AA: Ruthrieston
# Panini Express
# -------------------------------------------------
# 4.4 Very Good(135)·Italian·Dessert·Pasta·Alcohol
# AB10 1AA: Ruthrieston
# Da Vinci Italian Restaurant
# -------------------------------------------------
# 4.8 Excellent(28)·Alcohol·Grocery
# AB10 1AA: Ruthrieston
# Premier Store
# -------------------------------------------------
# 4.2 Very Good(38)·Turkish·African
# AB10 1AA: Ruthrieston
# Richis Cafe
# -------------------------------------------------
# 4.0 Good(12)·Curry·Indian
# AB10 1AA: Ruthrieston
# Rassoi
# -------------------------------------------------
# 3.6 Good(165)·Indian·Kebab
# AB10 1AA: Ruthrieston
# Qismat 2 Takeway
# -------------------------------------------------
# 4.2 Very Good(139)·Italian·Pasta·Chicken·Drinks
# AB10 1AA: Ruthrieston
# Risotteria
# -------------------------------------------------
# Curry·American·Indian·Bagels
# AB10 1AA: Ruthrieston
# The Essence Indian Cuisine
# -------------------------------------------------
# 4.0 Good(68)·Burgers·Wings·Drinks·Chicken
# AB10 1AA: Ruthrieston
# Revolution – Burgers & Wings
# -------------------------------------------------
# 4.4 Very Good(159)·British·Burgers·Chicken·Steak
# AB10 1AA: Ruthrieston
# Miller & Carter
# -------------------------------------------------
# 4.3 Very Good(77)·Breakfast·Italian
# AB10 1AA: Ruthrieston
# Bev's Bistro
# -------------------------------------------------
# 4.6 Excellent(245)·British·Bagels
# AB10 1AA: Ruthrieston
# Bagels & Brownies
# -------------------------------------------------
# 4.4 Very Good(186)·Pizza·Burgers·Kebab
# AB10 1AA: Ruthrieston
# Istanbul
# -------------------------------------------------
# 3.7 Good(432)·Pizza·Burgers·Kebab·Chicken
# AB10 1AA: Ruthrieston
# Belmont Chicken
# -------------------------------------------------
# 3.4(148)·Burritos·Mexican·Drinks·Caribbean
# AB10 1AA: Ruthrieston
# Revolucion de Cuba
# -------------------------------------------------
# Thai
# AB10 1AA: Ruthrieston
# Happy House
# -------------------------------------------------
# Burritos·Mexican·Burgers
# AB10 1AA: Ruthrieston
# Fresh Mex
# -------------------------------------------------
# 4.2 Very Good(60)·American·Sandwiches
# AB10 1AA: Ruthrieston
# Melt Restaurant
# -------------------------------------------------
# 4.5 Excellent(29)·Chicken·British
# AB10 1AA: Ruthrieston
# Duck and Dog
# -------------------------------------------------
# 4.4 Very Good(500+)·American·Pasta·Burgers·Sandwiches
# AB10 1AA: Ruthrieston
# Flippin' Cheese
# -------------------------------------------------
# 4.1 Good(500+)·Burgers·British·Alcohol
# AB10 1AA: Ruthrieston
# Angus & Ale
# -------------------------------------------------
# 4.1 Good(500+)·Dessert·American·Ice cream
# AB10 1AA: Ruthrieston
# ORCHARD CAFE
# -------------------------------------------------
# 4.0 Good(94)·Chicken·Curry·Noodles·Chinese
# AB10 1AA: Ruthrieston
# Big Wok
# -------------------------------------------------
#
# AB10 1AA: Ruthrieston
# Equi's Ice Cream
# -------------------------------------------------
# 4.0 Good(154)·Chicken·Burritos·Burgers·Fried chicken
# AB10 1AA: Ruthrieston
# Red or Dead
# -------------------------------------------------
# 4.3 Very Good(140)·British·Breakfast·Brunch·Café
# AB10 1AA: Ruthrieston
# Cafe Society
# -------------------------------------------------
# Pizza·Burgers·Curry·Indian
# AB10 1AA: Ruthrieston
# Royal Masala Tandoori
# -------------------------------------------------
# AB10 1AA: Ruthrieston
# Beach Burger Shack
# -------------------------------------------------
# Sandwiches·Café·Salads·Coffee
# AB10 1AA: Ruthrieston
# The Hill Deli
# -------------------------------------------------
# Indian
# AB10 1AA: Ruthrieston
# Touch of Spice
# -------------------------------------------------
# 3.8 Good(363)·British·Breakfast
# AB10 1AA: Ruthrieston
# JJJ Food Court
# -------------------------------------------------
# Asian·Noodles
# AB10 1AA: Ruthrieston
# Lionel's
# -------------------------------------------------
# 3.7 Good(28)·Alcohol·British·French
# AB10 1AA: Ruthrieston
# The Tippling House
# -------------------------------------------------
# 3.8 Good(62)·British·Burgers·Pasta·Brunch
# AB10 1AA: Ruthrieston
# The Lounge Bar & Kitchen
# -------------------------------------------------
# Italian
# AB10 1AA: Ruthrieston
# Central Coffee
# -------------------------------------------------
# British·Burgers
# AB10 1AA: Ruthrieston
# The Spiritualist
# -------------------------------------------------
# 4.1 Good(351)·Curry·Chinese
# AB10 1AA: Ruthrieston
# Peking Garden
# -------------------------------------------------
# 3.6 Good(402)·Pizza·Curry·Indian
# AB10 1AA: Ruthrieston
# Maya Indian Takeaway
# -------------------------------------------------
# Dutch·Fries
# AB10 1AA: Ruthrieston
# Aberdam Dutch Fries
# -------------------------------------------------
# British·Café
# AB10 1AA: Ruthrieston
# Comic Bistro
# -------------------------------------------------
# American·British·Italian
# AB10 1AA: Ruthrieston
# The Luncheon
# -------------------------------------------------
# 3.8 Good(138)·Thai·Chicken·Seafood·Breakfast
# AB10 1AA: Ruthrieston
# Pad Thai
# -------------------------------------------------
# 3.9 Good(20)·Thai·Chicken
# AB10 1AA: Ruthrieston
# Bhan Thai
# -------------------------------------------------
# 4.3 Very Good(265)·Juices·Healthy·Drinks
# AB10 1AA: Ruthrieston
# Zumo
# -------------------------------------------------
# 4.4 Very Good(500+)·Mexican
# AB10 1AA: Ruthrieston
# Topolabamba
# -------------------------------------------------
# Thai·Curry·Noodles·Indian
# AB10 1AA: Ruthrieston
# Donian
# -------------------------------------------------
# Pizza·Indian
# AB10 1AA: Ruthrieston
# Ayaan Tandoori
# -------------------------------------------------
# 4.3 Very Good(74)·Indian·Chicken·Curry
# AB10 1AA: Ruthrieston
# Blue Moon Authentic Indian Cuisine
# -------------------------------------------------
# 4.5 Excellent(500+)·African
# AB10 1AA: Ruthrieston
# Tasty T
# -------------------------------------------------
# 4.5 Excellent(21)·Curry·Indian·Drinks
# AB10 1AA: Ruthrieston
# Currymount Indian Deli
# -------------------------------------------------
# 3.9 Good(29)·British·American·Burgers·Drinks
# AB10 1AA: Ruthrieston
# The Hop & Anchor
# -------------------------------------------------
# N/A
# AB10 1AA: Ruthrieston
# N/A
# -------------------------------------------------
# N/A
# --------------------------------------------------------------------------------------------
